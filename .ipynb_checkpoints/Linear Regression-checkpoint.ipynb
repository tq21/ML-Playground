# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn import metrics
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
import statsmodels.api as sm
from sklearn.feature_selection import RFE

# %%
df_raw = pd.read_csv('data/housing.csv')
df_raw.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ## Preprocessing:

# %%
df_raw.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
df_raw.isnull().any()
# Out:
# longitude             False
# latitude              False
# housing_median_age    False
# total_rooms           False
# total_bedrooms         True
# population            False
# households            False
# median_income         False
# median_house_value    False
# ocean_proximity       False
# dtype: bool

# %%
# replace missing values with median
median_val = df_raw['total_bedrooms'].median()
df_raw['total_bedrooms'].fillna(median_val, inplace=True)

# %%
# categorical features
df_raw['ocean_proximity'] = df_raw['ocean_proximity'].astype('category')
df_raw["ocean_proximity1"] = df_raw["ocean_proximity"].cat.codes
df_raw.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    ocean_proximity1
# 0                 3
# 1                 3
# ...

# %%
# features and target
df = df_raw.drop(['ocean_proximity'], axis=1)
X_df = df.drop(['median_house_value'], axis=1)
y_df = df[['median_house_value']]
y = y_df['median_house_value']

# %%
# feature standardizing
scaler = StandardScaler()
X = scaler.fit_transform(X_df)

# %%
print(X.shape)
# Out:
# (20640, 9)

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2342)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (14448, 9)
# (14448,)
# (6192, 9)
# (6192,)

# %% [markdown]
# ## Feature Selection:

# %%
g = sns.pairplot(df)

# %%
# Heatmap
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(15,12))
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
# select best features using F-test
best_features = SelectKBest(score_func=f_classif, k=9)
fit = best_features.fit(X_df,y)
scores = pd.DataFrame(fit.scores_)
cols = pd.DataFrame(X_df.columns)
feature_scores = pd.concat([scores, cols], axis=1)
feature_scores.columns = ['Feature','Score']
print(featureScores.nlargest(9,'Score'))
# Out:
#               Feature     Score
# 7       median_income  6.807190
# 3         total_rooms  1.554459
# 1            latitude  1.259511
# 8    ocean_proximity1  1.233929
# 6          households  1.204033
# 5          population  1.196320
# 4      total_bedrooms  1.148260
# 2  housing_median_age  1.115178
# 0           longitude  1.056533

# %%
model = LinearRegression()
rfe = RFE(model, 5)
X_rfe = rfe.fit_transform(X,y)
model.fit(X_rfe,y)
print("Num Features: %d" % rfe.n_features_)
print(rfe.support_)
print(rfe.ranking_)
print(X_df.columns)
# Out:
# Num Features: 5
# [ True  True False False False  True  True  True False]
# [1 1 4 3 2 1 1 1 5]
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity1'],
#       dtype='object')

# %%
nof_list=np.arange(1,10)           
high_score=0
#Variable to store the optimum features
nof=0 
score_list =[]
for n in range(len(nof_list)):
    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)
    model = LinearRegression()
    rfe = RFE(model,nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train,y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,y_train)
    score = model.score(X_test_rfe,y_test)
    score_list.append(score)
    if(score>high_score):
        high_score = score
        nof = nof_list[n]
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
# Out:
# Optimum number of features: 8
# Score with 8 features: 0.628477

# %%
cols = list(X_df.columns)
model = LinearRegression()
#Initializing RFE model
rfe = RFE(model, 8)             
#Transforming data using RFE
X_rfe = rfe.fit_transform(X,y)  
#Fitting the data to model
model.fit(X_rfe,y)
temp = pd.Series(rfe.support_,index = cols)
selected_features_rfe = temp[temp==True].index
print(selected_features_rfe)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income'],
#       dtype='object')

# %% [markdown]
# ## Linear Regression:

# %%
lr = LinearRegression()
lr = lr.fit(X_train, y_train)
print("intercept: {}".format(lr.intercept_))
print("coefficients: {}".format(lr.coef_))
# Out:
# intercept: 206905.3842353831
# coefficients: [-84937.96425402 -89721.93905991  14449.83645572 -14013.13451601
#   32346.63937368 -42125.83070898  29298.8958999   74962.58125245
#     282.63352522]

# %%
# predictions
y_pred = lr.predict(X_test)
rmse_lr = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
r2_lr = lr.score(X_train, y_train)
print("RMSE: {}".format(rmse_lr))
print("R2: {}".format(r2_lr))
# Out:
# RMSE: 69409.77313755431
# R2: 0.6313599137331068

# %% [markdown]
# ## Ridge Regression:

# %%
rr = RidgeCV()
rr = rr.fit(X_train, y_train)
print("intercept: {}".format(rr.intercept_))
print("coefficients: {}".format(rr.coef_))
print("alpha: {}".format(rr.alpha_))
# Out:
# intercept: 206907.38182019696
# coefficients: [-84001.0663173  -88801.51454825  14535.6818152  -13906.0314475
#   31996.56120851 -41897.84126053  29352.47378388  74984.02031598
#     372.26125434]
# alpha: 10.0

# %%
# predictions
y_pred = rr.predict(X_test)
rmse_rr = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
r2_rr = rr.score(X_train, y_train)
print("RMSE: {}".format(rmse_rr))
print("R2: {}".format(r2_lr))
# Out:
# RMSE: 69422.61859342475
# R2: 0.6313599137331068

# %% [markdown]
# ## Lasso Regression:

# %%
lasso = LassoCV()
lasso = lasso.fit(X_train, y_train)
print("intercept: {}".format(lasso.intercept_))
print("coefficients: {}".format(lasso.coef_))
print("alpha: {}".format(lasso.alpha_))
# Out:
# intercept: 206907.93734651164
# coefficients: [-84100.31988373 -88911.73691258  14503.02779717 -12612.78134052
#   31149.35833872 -41593.09832657  28645.41359639  74691.3401208
#     300.52986941]
# alpha: 78.96445028774191

# %%
# predictions
y_pred = lasso.predict(X_test)
rmse_lasso = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
r2_lasso = lasso.score(X_train, y_train)
print("RMSE: {}".format(rmse_lasso))
print("R2: {}".format(r2_lasso))
# Out:
# RMSE: 69441.7856994903
# R2: 0.631326123343799
